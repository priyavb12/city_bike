# %%
import os
from pathlib import Path
import pandas as pd
pd.set_option('max_colwidth',400)

# %%
#file to load

citi_bike_csv_load = Path('./Resources/JC-201908-citibike-tripdata.csv')

# %%
#read csv

citi_bike_df = pd.read_csv(citi_bike_csv_load)
citi_bike_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1           172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2           525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3           219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4           262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
#
#    start station id start station name  start station latitude  \
# 0              3205  JC Medical Center               40.716540
# 1              3279        Dixon Mills               40.721630
# 2              3199       Newport Pkwy               40.728745
# 3              3187          Warren St               40.721124
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id    end station name  \
# 0               -74.049638            3192  Liberty Light Rail
# 1               -74.049968            3186       Grove St PATH
# 2               -74.032108            3203       Hamilton Park
# 3               -74.038051            3185           City Hall
# 4               -74.043117            3272        Jersey & 3rd
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.711242             -74.055701   26268  Subscriber
# 1             40.719586             -74.043117   26162  Subscriber
# 2             40.727596             -74.044247   29279  Subscriber
# 3             40.717732             -74.043845   29598  Subscriber
# 4             40.723332             -74.045953   26162  Subscriber
#
#    birth year  gender
# 0        1980       1
# 1        1996       1
# 2        1991       1
# 3        1988       1
# 4        1960       1

# %%
#find datatype in dataframe

citi_bike_df = pd.read_csv('./Resources/JC-201908-citibike-tripdata.csv')

print(type(citi_bike_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
citi_bike_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
#check for null values
citi_bike_df.isnull().sum()
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# dtype: int64

# %%
#check for duplicates

citi_bike_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48706    False
# 48707    False
# 48708    False
# 48709    False
# 48710    False
# Length: 48711, dtype: bool

# %%
citi_bike_df.duplicated().sum()
# Out:
# 0

# %%
citi_bike_df.columns =citi_bike_df.columns.str.replace(' ' ,'_')

# %%
citi_bike_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1           172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2           525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3           219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4           262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
#
#    start_station_id start_station_name  start_station_latitude  \
# 0              3205  JC Medical Center               40.716540
# 1              3279        Dixon Mills               40.721630
# 2              3199       Newport Pkwy               40.728745
# 3              3187          Warren St               40.721124
# 4              3186      Grove St PATH               40.719586
#
#    start_station_longitude  end_station_id    end_station_name  \
# 0               -74.049638            3192  Liberty Light Rail
# 1               -74.049968            3186       Grove St PATH
# 2               -74.032108            3203       Hamilton Park
# 3               -74.038051            3185           City Hall
# 4               -74.043117            3272        Jersey & 3rd
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.711242             -74.055701   26268  Subscriber
# 1             40.719586             -74.043117   26162  Subscriber
# 2             40.727596             -74.044247   29279  Subscriber
# 3             40.717732             -74.043845   29598  Subscriber
# 4             40.723332             -74.045953   26162  Subscriber
#
#    birth_year  gender
# 0        1980       1
# 1        1996       1
# 2        1991       1
# 3        1988       1
# 4        1960       1

# %%
citi_bike_df['starttime'] = pd.to_datetime(citi_bike_df['starttime'])
citi_bike_df['starttime'] = citi_bike_df['starttime'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
citi_bike_df.tail()
# Out:
#        tripduration            starttime                  stoptime  \
# 48706           384  2019-08-31 23:40:45  2019-08-31 23:47:09.8810
# 48707           633  2019-08-31 23:45:55  2019-08-31 23:56:29.5350
# 48708           324  2019-08-31 23:50:27  2019-08-31 23:55:52.8420
# 48709           126  2019-08-31 23:52:21  2019-08-31 23:54:28.5820
# 48710           690  2019-08-31 23:56:55  2019-09-01 00:08:25.2370
#
#        start_station_id start_station_name  start_station_latitude  \
# 48706              3639         Harborside               40.719252
# 48707              3186      Grove St PATH               40.719586
# 48708              3276   Marin Light Rail               40.714584
# 48709              3211         Newark Ave               40.721525
# 48710              3185          City Hall               40.717732
#
#        start_station_longitude  end_station_id         end_station_name  \
# 48706               -74.034234            3203            Hamilton Park
# 48707               -74.043117            3185                City Hall
# 48708               -74.042817            3211               Newark Ave
# 48709               -74.046305            3209             Brunswick St
# 48710               -74.043845            3277  Communipaw & Berry Lane
#
#        end_station_latitude  end_station_longitude  bikeid    usertype  \
# 48706             40.727596             -74.044247   29522  Subscriber
# 48707             40.717732             -74.043845   29679    Customer
# 48708             40.721525             -74.046305   26198  Subscriber
# 48709             40.724176             -74.050656   29512  Subscriber
# 48710             40.714358             -74.066611   26223  Subscriber
#
#        birth_year  gender
# 48706        1988       1
# 48707        1997       1
# 48708        1997       2
# 48709        1998       1
# 48710        1992       1

# %%
citi_bike_df['stoptime'] = pd.to_datetime(citi_bike_df['stoptime'])
citi_bike_df['stoptime'] = citi_bike_df['stoptime'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
citi_bike_df
# Out:
#        tripduration            starttime             stoptime  \
# 0               261  2019-08-01 00:14:55  2019-08-01 00:19:17
# 1               172  2019-08-01 00:23:06  2019-08-01 00:25:59
# 2               525  2019-08-01 00:23:28  2019-08-01 00:32:13
# 3               219  2019-08-01 00:32:36  2019-08-01 00:36:15
# 4               262  2019-08-01 00:41:26  2019-08-01 00:45:49
# ...             ...                  ...                  ...
# 48706           384  2019-08-31 23:40:45  2019-08-31 23:47:09
# 48707           633  2019-08-31 23:45:55  2019-08-31 23:56:29
# 48708           324  2019-08-31 23:50:27  2019-08-31 23:55:52
# 48709           126  2019-08-31 23:52:21  2019-08-31 23:54:28
# 48710           690  2019-08-31 23:56:55  2019-09-01 00:08:25
#
#        start_station_id start_station_name  start_station_latitude  \
# 0                  3205  JC Medical Center               40.716540
# 1                  3279        Dixon Mills               40.721630
# 2                  3199       Newport Pkwy               40.728745
# 3                  3187          Warren St               40.721124
# 4                  3186      Grove St PATH               40.719586
# ...                 ...                ...                     ...
# 48706              3639         Harborside               40.719252
# 48707              3186      Grove St PATH               40.719586
# 48708              3276   Marin Light Rail               40.714584
# 48709              3211         Newark Ave               40.721525
# 48710              3185          City Hall               40.717732
#
#        start_station_longitude  end_station_id         end_station_name  \
# 0                   -74.049638            3192       Liberty Light Rail
# 1                   -74.049968            3186            Grove St PATH
# 2                   -74.032108            3203            Hamilton Park
# 3                   -74.038051            3185                City Hall
# 4                   -74.043117            3272             Jersey & 3rd
# ...                        ...             ...                      ...
# 48706               -74.034234            3203            Hamilton Park
# 48707               -74.043117            3185                City Hall
# 48708               -74.042817            3211               Newark Ave
# 48709               -74.046305            3209             Brunswick St
# 48710               -74.043845            3277  Communipaw & Berry Lane
#
#        end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0                 40.711242             -74.055701   26268  Subscriber
# 1                 40.719586             -74.043117   26162  Subscriber
# 2                 40.727596             -74.044247   29279  Subscriber
# 3                 40.717732             -74.043845   29598  Subscriber
# 4                 40.723332             -74.045953   26162  Subscriber
# ...                     ...                    ...     ...         ...
# 48706             40.727596             -74.044247   29522  Subscriber
# 48707             40.717732             -74.043845   29679    Customer
# 48708             40.721525             -74.046305   26198  Subscriber
# 48709             40.724176             -74.050656   29512  Subscriber
# 48710             40.714358             -74.066611   26223  Subscriber
#
#        birth_year  gender
# 0            1980       1
# 1            1996       1
# 2            1991       1
# 3            1988       1
# 4            1960       1
# ...           ...     ...
# 48706        1988       1
# 48707        1997       1
# 48708        1997       2
# 48709        1998       1
# 48710        1992       1
#
# [48711 rows x 15 columns]

# %%
citi_bike_df = citi_bike_df.copy()

# %%
print(citi_bike_df[['starttime', 'stoptime']].head(10))
# Out:
#              starttime             stoptime
# 0  2019-08-01 00:14:55  2019-08-01 00:19:17
# 1  2019-08-01 00:23:06  2019-08-01 00:25:59
# 2  2019-08-01 00:23:28  2019-08-01 00:32:13
# 3  2019-08-01 00:32:36  2019-08-01 00:36:15
# 4  2019-08-01 00:41:26  2019-08-01 00:45:49
# 5  2019-08-01 00:43:15  2019-08-01 00:56:55
# 6  2019-08-01 00:52:59  2019-08-01 01:02:02
# 7  2019-08-01 01:00:40  2019-08-01 01:08:39
# 8  2019-08-01 01:14:10  2019-08-01 01:59:12
# 9  2019-08-01 01:49:05  2019-08-01 01:59:52

# %%
citi_bike_df['starttime'] = pd.to_datetime(citi_bike_df['starttime'], errors='coerce')
citi_bike_df['stoptime'] = pd.to_datetime(citi_bike_df['stoptime'], errors='coerce')

citi_bike_df.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start_station_id                    int64
# start_station_name                 object
# start_station_latitude            float64
# start_station_longitude           float64
# end_station_id                      int64
# end_station_name                   object
# end_station_latitude              float64
# end_station_longitude             float64
# bikeid                              int64
# usertype                           object
# birth_year                          int64
# gender                              int64
# dtype: object

# %%
citi_bike_df.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start_station_id                    int64
# start_station_name                 object
# start_station_latitude            float64
# start_station_longitude           float64
# end_station_id                      int64
# end_station_name                   object
# end_station_latitude              float64
# end_station_longitude             float64
# bikeid                              int64
# usertype                           object
# birth_year                          int64
# gender                              int64
# dtype: object

# %%
citi_bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48711 entries, 0 to 48710
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             48711 non-null  int64
#  1   starttime                48711 non-null  datetime64[ns]
#  2   stoptime                 48711 non-null  datetime64[ns]
#  3   start_station_id         48711 non-null  int64
#  4   start_station_name       48711 non-null  object
#  5   start_station_latitude   48711 non-null  float64
#  6   start_station_longitude  48711 non-null  float64
#  7   end_station_id           48711 non-null  int64
#  8   end_station_name         48711 non-null  object
#  9   end_station_latitude     48711 non-null  float64
#  10  end_station_longitude    48711 non-null  float64
#  11  bikeid                   48711 non-null  int64
#  12  usertype                 48711 non-null  object
#  13  birth_year               48711 non-null  int64
#  14  gender                   48711 non-null  int64
# dtypes: datetime64[ns](2), float64(4), int64(6), object(3)
# memory usage: 5.6+ MB

# %%
citi_bike_df
# Out:
#        tripduration           starttime            stoptime  start_station_id  \
# 0               261 2019-08-01 00:14:55 2019-08-01 00:19:17              3205
# 1               172 2019-08-01 00:23:06 2019-08-01 00:25:59              3279
# 2               525 2019-08-01 00:23:28 2019-08-01 00:32:13              3199
# 3               219 2019-08-01 00:32:36 2019-08-01 00:36:15              3187
# 4               262 2019-08-01 00:41:26 2019-08-01 00:45:49              3186
# ...             ...                 ...                 ...               ...
# 48706           384 2019-08-31 23:40:45 2019-08-31 23:47:09              3639
# 48707           633 2019-08-31 23:45:55 2019-08-31 23:56:29              3186
# 48708           324 2019-08-31 23:50:27 2019-08-31 23:55:52              3276
# 48709           126 2019-08-31 23:52:21 2019-08-31 23:54:28              3211
# 48710           690 2019-08-31 23:56:55 2019-09-01 00:08:25              3185
#
#       start_station_name  start_station_latitude  start_station_longitude  \
# 0      JC Medical Center               40.716540               -74.049638
# 1            Dixon Mills               40.721630               -74.049968
# 2           Newport Pkwy               40.728745               -74.032108
# 3              Warren St               40.721124               -74.038051
# 4          Grove St PATH               40.719586               -74.043117
# ...                  ...                     ...                      ...
# 48706         Harborside               40.719252               -74.034234
# 48707      Grove St PATH               40.719586               -74.043117
# 48708   Marin Light Rail               40.714584               -74.042817
# 48709         Newark Ave               40.721525               -74.046305
# 48710          City Hall               40.717732               -74.043845
#
#        end_station_id         end_station_name  end_station_latitude  \
# 0                3192       Liberty Light Rail             40.711242
# 1                3186            Grove St PATH             40.719586
# 2                3203            Hamilton Park             40.727596
# 3                3185                City Hall             40.717732
# 4                3272             Jersey & 3rd             40.723332
# ...               ...                      ...                   ...
# 48706            3203            Hamilton Park             40.727596
# 48707            3185                City Hall             40.717732
# 48708            3211               Newark Ave             40.721525
# 48709            3209             Brunswick St             40.724176
# 48710            3277  Communipaw & Berry Lane             40.714358
#
#        end_station_longitude  bikeid    usertype  birth_year  gender
# 0                 -74.055701   26268  Subscriber        1980       1
# 1                 -74.043117   26162  Subscriber        1996       1
# 2                 -74.044247   29279  Subscriber        1991       1
# 3                 -74.043845   29598  Subscriber        1988       1
# 4                 -74.045953   26162  Subscriber        1960       1
# ...                      ...     ...         ...         ...     ...
# 48706             -74.044247   29522  Subscriber        1988       1
# 48707             -74.043845   29679    Customer        1997       1
# 48708             -74.046305   26198  Subscriber        1997       2
# 48709             -74.050656   29512  Subscriber        1998       1
# 48710             -74.066611   26223  Subscriber        1992       1
#
# [48711 rows x 15 columns]

# %%
citi_bike_df.copy()
# Out:
#        tripduration           starttime            stoptime  start_station_id  \
# 0               261 2019-08-01 00:14:55 2019-08-01 00:19:17              3205
# 1               172 2019-08-01 00:23:06 2019-08-01 00:25:59              3279
# 2               525 2019-08-01 00:23:28 2019-08-01 00:32:13              3199
# 3               219 2019-08-01 00:32:36 2019-08-01 00:36:15              3187
# 4               262 2019-08-01 00:41:26 2019-08-01 00:45:49              3186
# ...             ...                 ...                 ...               ...
# 48706           384 2019-08-31 23:40:45 2019-08-31 23:47:09              3639
# 48707           633 2019-08-31 23:45:55 2019-08-31 23:56:29              3186
# 48708           324 2019-08-31 23:50:27 2019-08-31 23:55:52              3276
# 48709           126 2019-08-31 23:52:21 2019-08-31 23:54:28              3211
# 48710           690 2019-08-31 23:56:55 2019-09-01 00:08:25              3185
#
#       start_station_name  start_station_latitude  start_station_longitude  \
# 0      JC Medical Center               40.716540               -74.049638
# 1            Dixon Mills               40.721630               -74.049968
# 2           Newport Pkwy               40.728745               -74.032108
# 3              Warren St               40.721124               -74.038051
# 4          Grove St PATH               40.719586               -74.043117
# ...                  ...                     ...                      ...
# 48706         Harborside               40.719252               -74.034234
# 48707      Grove St PATH               40.719586               -74.043117
# 48708   Marin Light Rail               40.714584               -74.042817
# 48709         Newark Ave               40.721525               -74.046305
# 48710          City Hall               40.717732               -74.043845
#
#        end_station_id         end_station_name  end_station_latitude  \
# 0                3192       Liberty Light Rail             40.711242
# 1                3186            Grove St PATH             40.719586
# 2                3203            Hamilton Park             40.727596
# 3                3185                City Hall             40.717732
# 4                3272             Jersey & 3rd             40.723332
# ...               ...                      ...                   ...
# 48706            3203            Hamilton Park             40.727596
# 48707            3185                City Hall             40.717732
# 48708            3211               Newark Ave             40.721525
# 48709            3209             Brunswick St             40.724176
# 48710            3277  Communipaw & Berry Lane             40.714358
#
#        end_station_longitude  bikeid    usertype  birth_year  gender
# 0                 -74.055701   26268  Subscriber        1980       1
# 1                 -74.043117   26162  Subscriber        1996       1
# 2                 -74.044247   29279  Subscriber        1991       1
# 3                 -74.043845   29598  Subscriber        1988       1
# 4                 -74.045953   26162  Subscriber        1960       1
# ...                      ...     ...         ...         ...     ...
# 48706             -74.044247   29522  Subscriber        1988       1
# 48707             -74.043845   29679    Customer        1997       1
# 48708             -74.046305   26198  Subscriber        1997       2
# 48709             -74.050656   29512  Subscriber        1998       1
# 48710             -74.066611   26223  Subscriber        1992       1
#
# [48711 rows x 15 columns]

# %%
# Convert tripduration from seconds to a timedelta
citi_bike_df['tripduration_timedelta'] = pd.to_timedelta(citi_bike_df['tripduration'], unit='s')

# Display the DataFrame
citi_bike_df
# Out:
#        tripduration           starttime            stoptime  start_station_id  \
# 0               261 2019-08-01 00:14:55 2019-08-01 00:19:17              3205
# 1               172 2019-08-01 00:23:06 2019-08-01 00:25:59              3279
# 2               525 2019-08-01 00:23:28 2019-08-01 00:32:13              3199
# 3               219 2019-08-01 00:32:36 2019-08-01 00:36:15              3187
# 4               262 2019-08-01 00:41:26 2019-08-01 00:45:49              3186
# ...             ...                 ...                 ...               ...
# 48706           384 2019-08-31 23:40:45 2019-08-31 23:47:09              3639
# 48707           633 2019-08-31 23:45:55 2019-08-31 23:56:29              3186
# 48708           324 2019-08-31 23:50:27 2019-08-31 23:55:52              3276
# 48709           126 2019-08-31 23:52:21 2019-08-31 23:54:28              3211
# 48710           690 2019-08-31 23:56:55 2019-09-01 00:08:25              3185
#
#       start_station_name  start_station_latitude  start_station_longitude  \
# 0      JC Medical Center               40.716540               -74.049638
# 1            Dixon Mills               40.721630               -74.049968
# 2           Newport Pkwy               40.728745               -74.032108
# 3              Warren St               40.721124               -74.038051
# 4          Grove St PATH               40.719586               -74.043117
# ...                  ...                     ...                      ...
# 48706         Harborside               40.719252               -74.034234
# 48707      Grove St PATH               40.719586               -74.043117
# 48708   Marin Light Rail               40.714584               -74.042817
# 48709         Newark Ave               40.721525               -74.046305
# 48710          City Hall               40.717732               -74.043845
#
#        end_station_id         end_station_name  end_station_latitude  \
# 0                3192       Liberty Light Rail             40.711242
# 1                3186            Grove St PATH             40.719586
# 2                3203            Hamilton Park             40.727596
# 3                3185                City Hall             40.717732
# 4                3272             Jersey & 3rd             40.723332
# ...               ...                      ...                   ...
# 48706            3203            Hamilton Park             40.727596
# 48707            3185                City Hall             40.717732
# 48708            3211               Newark Ave             40.721525
# 48709            3209             Brunswick St             40.724176
# 48710            3277  Communipaw & Berry Lane             40.714358
#
#        end_station_longitude  bikeid    usertype  birth_year  gender  \
# 0                 -74.055701   26268  Subscriber        1980       1
# 1                 -74.043117   26162  Subscriber        1996       1
# 2                 -74.044247   29279  Subscriber        1991       1
# 3                 -74.043845   29598  Subscriber        1988       1
# 4                 -74.045953   26162  Subscriber        1960       1
# ...                      ...     ...         ...         ...     ...
# 48706             -74.044247   29522  Subscriber        1988       1
# 48707             -74.043845   29679    Customer        1997       1
# 48708             -74.046305   26198  Subscriber        1997       2
# 48709             -74.050656   29512  Subscriber        1998       1
# 48710             -74.066611   26223  Subscriber        1992       1
#
#       tripduration_timedelta
# 0            0 days 00:04:21
# 1            0 days 00:02:52
# 2            0 days 00:08:45
# 3            0 days 00:03:39
# 4            0 days 00:04:22
# ...                      ...
# 48706        0 days 00:06:24
# 48707        0 days 00:10:33
# 48708        0 days 00:05:24
# 48709        0 days 00:02:06
# 48710        0 days 00:11:30
#
# [48711 rows x 16 columns]

# %%
citi_bike_df.to_csv('citi_bike.csv')
